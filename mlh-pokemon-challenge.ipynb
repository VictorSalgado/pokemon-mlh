# %%
import numpy as np
import pandas as pd
import tensorflow as tf 

from sklearn.ensemble import GradientBoostingClassifier

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

import os
print(os.listdir("input/"))
# Out:
# ['.DS_Store', 'battles.csv', 'test.csv', 'pokemon.csv', 'typetable.csv']

# %%
import re
to_underscore = lambda x: re.sub("[^0-9a-zA-Z#]+", "_", x.lower())

# %%
# Retrieve the data
pokemon = pd.read_csv('input/pokemon.csv').rename(to_underscore, axis='columns').fillna("None")
battles = pd.read_csv('input/battles.csv').rename(to_underscore, axis='columns').fillna("None")
test = pd.read_csv('input/test.csv').rename(to_underscore, axis='columns').fillna("None")
typetable = pd.read_csv('input/typetable.csv')

# Show data structure
print("pokemon", pokemon.shape)
print("battles", battles.shape)
print("test", test.shape)
print("typetable", typetable.shape)
# Out:
# pokemon (800, 12)
# battles (50000, 4)
# test (10000, 3)
# typetable (18, 19)

# %%
# Show pokemon file content
pokemon = pokemon.drop(labels=["name"], axis=1)
pokemon = pokemon.fillna({'Type 2': 'None'})
pokemon.head()
# Out:
#    # type_1  type_2  hp  attack  defense  sp_atk  sp_def  speed  generation  \
# 0  1  Grass  Poison  45      49       49      65      65     45           1
# 1  2  Grass  Poison  60      62       63      80      80     60           1
# 2  3  Grass  Poison  80      82       83     100     100     80           1
# 3  4  Grass  Poison  80     100      123     122     120     80           1
# 4  5   Fire    None  39      52       43      60      50     65           1
#
#    legendary
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False

# %%
# Normalize columns with continious values
columns = ['attack', 'defense', 'hp', 'speed', 'sp_atk', 'sp_def']
pokemon[columns] = MinMaxScaler().fit_transform(pokemon[columns])
pokemon.head()
# Out:
#    # type_1  type_2        hp    attack   defense    sp_atk    sp_def  \
# 0  1  Grass  Poison  0.173228  0.237838  0.195556  0.298913  0.214286
# 1  2  Grass  Poison  0.232283  0.308108  0.257778  0.380435  0.285714
# 2  3  Grass  Poison  0.311024  0.416216  0.346667  0.489130  0.380952
# 3  4  Grass  Poison  0.311024  0.513514  0.524444  0.608696  0.476190
# 4  5   Fire    None  0.149606  0.254054  0.168889  0.271739  0.142857
#
#       speed  generation  legendary
# 0  0.228571           1      False
# 1  0.314286           1      False
# 2  0.428571           1      False
# 3  0.428571           1      False
# 4  0.342857           1      False

# %%
# Change boolean type to 0 & 1 values
pokemon["legendary"] = pokemon["legendary"].astype(int)
pokemon.head()
# Out:
#    # type_1  type_2        hp    attack   defense    sp_atk    sp_def  \
# 0  1  Grass  Poison  0.173228  0.237838  0.195556  0.298913  0.214286
# 1  2  Grass  Poison  0.232283  0.308108  0.257778  0.380435  0.285714
# 2  3  Grass  Poison  0.311024  0.416216  0.346667  0.489130  0.380952
# 3  4  Grass  Poison  0.311024  0.513514  0.524444  0.608696  0.476190
# 4  5   Fire    None  0.149606  0.254054  0.168889  0.271739  0.142857
#
#       speed  generation  legendary
# 0  0.228571           1          0
# 1  0.314286           1          0
# 2  0.428571           1          0
# 3  0.428571           1          0
# 4  0.342857           1          0

# %%
# Create new multiplier to get the type effectivity between pokemons
vals = []

for c1 in typetable.columns[1:]:
    
    # Values when the defensor just have one type
    vals.append(pd.DataFrame({
        "idx": typetable["atck"].map(lambda x: "%s-vs-%s-None" % (x, c1)), #.rename(None)
        "mul": typetable[c1],
    }))
    
    # Values when the defensor have two types
    for c2 in typetable.columns[1:]:
        vals.append(pd.DataFrame({
            "idx": typetable["atck"].map(lambda x: "%s-vs-%s-%s" % (x, c1, c2)), #.rename(None)
            "mul": typetable[c1] * typetable[c2],
        }))
        
# Transform dataset to dicctionary 
mult = pd.concat(vals).reset_index().drop(["index"], axis=1)
mult = dict(zip(mult.values[:,0], mult.values[:,1]))

def multiplier(cat):
    return mult.get(cat, 0)

mult
# Out:
# {'Normal-vs-Normal-None': 1.0,
#  'Fighting-vs-Normal-None': 2.0,
#  'Flying-vs-Normal-None': 1.0,
#  'Poison-vs-Normal-None': 1.0,
#  'Ground-vs-Normal-None': 1.0,
#  'Rock-vs-Normal-None': 1.0,
#  'Bug-vs-Normal-None': 1.0,
#  'Ghost-vs-Normal-None': 0.0,
#  'Steel-vs-Normal-None': 1.0,
#  'Fire-vs-Normal-None': 1.0,
#  'Water-vs-Normal-None': 1.0,
#  'Grass-vs-Normal-None': 1.0,
#  'Electric-vs-Normal-None': 1.0,
#  'Psychic-vs-Normal-None': 1.0,
#  'Ice-vs-Normal-None': 1.0,
#  'Dragon-vs-Normal-None': 1.0,
#  'Dark-vs-Normal-None': 1.0,
#  'Fairy-vs-Normal-None': 1.0,
#  'Normal-vs-Normal-Normal': 1.0,
#  'Fighting-vs-Normal-Normal': 4.0,
#  'Flying-vs-Normal-Normal': 1.0,
#  'Poison-vs-Normal-Normal': 1.0,
#  'Ground-vs-Normal-Normal': 1.0,
#  'Rock-vs-Normal-Normal': 1.0,
#  'Bug-vs-Normal-Normal': 1.0,
#  'Ghost-vs-Normal-Normal': 0.0,
#  'Steel-vs-Normal-Normal': 1.0,
#  'Fire-vs-Normal-Normal': 1.0,
#  'Water-vs-Normal-Normal': 1.0,
#  'Grass-vs-Normal-Normal': 1.0,
#  'Electric-vs-Normal-Normal': 1.0,
#  'Psychic-vs-Normal-Normal': 1.0,
#  'Ice-vs-Normal-Normal': 1.0,
#  'Dragon-vs-Normal-Normal': 1.0,
#  'Dark-vs-Normal-Normal': 1.0,
#  'Fairy-vs-Normal-Normal': 1.0,
#  'Normal-vs-Normal-Fighting': 1.0,
#  'Fighting-vs-Normal-Fighting': 2.0,
#  'Flying-vs-Normal-Fighting': 2.0,
#  'Poison-vs-Normal-Fighting': 1.0,
#  'Ground-vs-Normal-Fighting': 1.0,
#  'Rock-vs-Normal-Fighting': 0.5,
#  'Bug-vs-Normal-Fighting': 0.5,
#  'Ghost-vs-Normal-Fighting': 0.0,
#  'Steel-vs-Normal-Fighting': 1.0,
#  'Fire-vs-Normal-Fighting': 1.0,
#  'Water-vs-Normal-Fighting': 1.0,
#  'Grass-vs-Normal-Fighting': 1.0,
#  'Electric-vs-Normal-Fighting': 1.0,
#  'Psychic-vs-Normal-Fighting': 2.0,
#  'Ice-vs-Normal-Fighting': 1.0,
#  'Dragon-vs-Normal-Fighting': 1.0,
#  'Dark-vs-Normal-Fighting': 0.5,
#  'Fairy-vs-Normal-Fighting': 2.0,
#  'Normal-vs-Normal-Flying': 1.0,
#  'Fighting-vs-Normal-Flying': 1.0,
#  'Flying-vs-Normal-Flying': 1.0,
#  'Poison-vs-Normal-Flying': 1.0,
#  'Ground-vs-Normal-Flying': 0.0,
#  'Rock-vs-Normal-Flying': 2.0,
#  'Bug-vs-Normal-Flying': 0.5,
#  'Ghost-vs-Normal-Flying': 0.0,
#  'Steel-vs-Normal-Flying': 1.0,
#  'Fire-vs-Normal-Flying': 1.0,
#  'Water-vs-Normal-Flying': 1.0,
#  'Grass-vs-Normal-Flying': 0.5,
#  'Electric-vs-Normal-Flying': 2.0,
#  'Psychic-vs-Normal-Flying': 1.0,
#  'Ice-vs-Normal-Flying': 2.0,
#  'Dragon-vs-Normal-Flying': 1.0,
#  'Dark-vs-Normal-Flying': 1.0,
#  'Fairy-vs-Normal-Flying': 1.0,
#  'Normal-vs-Normal-Poison': 1.0,
#  'Fighting-vs-Normal-Poison': 1.0,
#  'Flying-vs-Normal-Poison': 1.0,
#  'Poison-vs-Normal-Poison': 0.5,
#  'Ground-vs-Normal-Poison': 2.0,
#  'Rock-vs-Normal-Poison': 1.0,
#  'Bug-vs-Normal-Poison': 0.5,
#  'Ghost-vs-Normal-Poison': 0.0,
#  'Steel-vs-Normal-Poison': 1.0,
#  'Fire-vs-Normal-Poison': 1.0,
#  'Water-vs-Normal-Poison': 1.0,
#  'Grass-vs-Normal-Poison': 0.5,
#  'Electric-vs-Normal-Poison': 1.0,
#  'Psychic-vs-Normal-Poison': 2.0,
#  'Ice-vs-Normal-Poison': 1.0,
#  'Dragon-vs-Normal-Poison': 1.0,
#  'Dark-vs-Normal-Poison': 1.0,
#  'Fairy-vs-Normal-Poison': 0.5,
#  'Normal-vs-Normal-Ground': 1.0,
#  'Fighting-vs-Normal-Ground': 2.0,
#  'Flying-vs-Normal-Ground': 1.0,
#  'Poison-vs-Normal-Ground': 0.5,
#  'Ground-vs-Normal-Ground': 1.0,
#  'Rock-vs-Normal-Ground': 0.5,
#  'Bug-vs-Normal-Ground': 1.0,
#  'Ghost-vs-Normal-Ground': 0.0,
#  'Steel-vs-Normal-Ground': 1.0,
#  'Fire-vs-Normal-Ground': 1.0,
#  'Water-vs-Normal-Ground': 2.0,
#  'Grass-vs-Normal-Ground': 2.0,
#  'Electric-vs-Normal-Ground': 0.0,
#  'Psychic-vs-Normal-Ground': 1.0,
#  'Ice-vs-Normal-Ground': 2.0,
#  'Dragon-vs-Normal-Ground': 1.0,
#  'Dark-vs-Normal-Ground': 1.0,
#  'Fairy-vs-Normal-Ground': 1.0,
#  'Normal-vs-Normal-Rock': 0.5,
#  'Fighting-vs-Normal-Rock': 4.0,
#  'Flying-vs-Normal-Rock': 0.5,
#  'Poison-vs-Normal-Rock': 0.5,
#  'Ground-vs-Normal-Rock': 2.0,
#  'Rock-vs-Normal-Rock': 1.0,
#  'Bug-vs-Normal-Rock': 1.0,
#  'Ghost-vs-Normal-Rock': 0.0,
#  'Steel-vs-Normal-Rock': 2.0,
#  'Fire-vs-Normal-Rock': 0.5,
#  'Water-vs-Normal-Rock': 2.0,
#  'Grass-vs-Normal-Rock': 2.0,
#  'Electric-vs-Normal-Rock': 1.0,
#  'Psychic-vs-Normal-Rock': 1.0,
#  'Ice-vs-Normal-Rock': 1.0,
#  'Dragon-vs-Normal-Rock': 1.0,
#  'Dark-vs-Normal-Rock': 1.0,
#  'Fairy-vs-Normal-Rock': 1.0,
#  'Normal-vs-Normal-Bug': 1.0,
#  'Fighting-vs-Normal-Bug': 1.0,
#  'Flying-vs-Normal-Bug': 2.0,
#  'Poison-vs-Normal-Bug': 1.0,
#  'Ground-vs-Normal-Bug': 0.5,
#  'Rock-vs-Normal-Bug': 2.0,
#  'Bug-vs-Normal-Bug': 1.0,
#  'Ghost-vs-Normal-Bug': 0.0,
#  'Steel-vs-Normal-Bug': 1.0,
#  'Fire-vs-Normal-Bug': 2.0,
#  'Water-vs-Normal-Bug': 1.0,
#  'Grass-vs-Normal-Bug': 0.5,
#  'Electric-vs-Normal-Bug': 1.0,
#  'Psychic-vs-Normal-Bug': 1.0,
#  'Ice-vs-Normal-Bug': 1.0,
#  'Dragon-vs-Normal-Bug': 1.0,
#  'Dark-vs-Normal-Bug': 1.0,
#  'Fairy-vs-Normal-Bug': 1.0,
#  'Normal-vs-Normal-Ghost': 0.0,
#  'Fighting-vs-Normal-Ghost': 0.0,
#  'Flying-vs-Normal-Ghost': 1.0,
#  'Poison-vs-Normal-Ghost': 0.5,
#  'Ground-vs-Normal-Ghost': 1.0,
#  'Rock-vs-Normal-Ghost': 1.0,
#  'Bug-vs-Normal-Ghost': 0.5,
#  'Ghost-vs-Normal-Ghost': 0.0,
#  'Steel-vs-Normal-Ghost': 1.0,
#  'Fire-vs-Normal-Ghost': 1.0,
#  'Water-vs-Normal-Ghost': 1.0,
#  'Grass-vs-Normal-Ghost': 1.0,
#  'Electric-vs-Normal-Ghost': 1.0,
#  'Psychic-vs-Normal-Ghost': 1.0,
#  'Ice-vs-Normal-Ghost': 1.0,
#  'Dragon-vs-Normal-Ghost': 1.0,
#  'Dark-vs-Normal-Ghost': 2.0,
#  'Fairy-vs-Normal-Ghost': 1.0,
#  'Normal-vs-Normal-Steel': 0.5,
#  'Fighting-vs-Normal-Steel': 4.0,
#  'Flying-vs-Normal-Steel': 0.5,
#  'Poison-vs-Normal-Steel': 0.0,
#  'Ground-vs-Normal-Steel': 2.0,
#  'Rock-vs-Normal-Steel': 0.5,
#  'Bug-vs-Normal-Steel': 0.5,
#  'Ghost-vs-Normal-Steel': 0.0,
#  'Steel-vs-Normal-Steel': 0.5,
#  'Fire-vs-Normal-Steel': 2.0,
#  'Water-vs-Normal-Steel': 1.0,
#  'Grass-vs-Normal-Steel': 0.5,
#  'Electric-vs-Normal-Steel': 1.0,
#  'Psychic-vs-Normal-Steel': 0.5,
#  'Ice-vs-Normal-Steel': 0.5,
#  'Dragon-vs-Normal-Steel': 0.5,
#  'Dark-vs-Normal-Steel': 1.0,
#  'Fairy-vs-Normal-Steel': 0.5,
#  'Normal-vs-Normal-Fire': 1.0,
#  'Fighting-vs-Normal-Fire': 2.0,
#  'Flying-vs-Normal-Fire': 1.0,
#  'Poison-vs-Normal-Fire': 1.0,
#  'Ground-vs-Normal-Fire': 2.0,
#  'Rock-vs-Normal-Fire': 2.0,
#  'Bug-vs-Normal-Fire': 0.5,
#  'Ghost-vs-Normal-Fire': 0.0,
#  'Steel-vs-Normal-Fire': 0.5,
#  'Fire-vs-Normal-Fire': 0.5,
#  'Water-vs-Normal-Fire': 2.0,
#  'Grass-vs-Normal-Fire': 0.5,
#  'Electric-vs-Normal-Fire': 1.0,
#  'Psychic-vs-Normal-Fire': 1.0,
#  'Ice-vs-Normal-Fire': 0.5,
#  'Dragon-vs-Normal-Fire': 1.0,
#  'Dark-vs-Normal-Fire': 1.0,
#  'Fairy-vs-Normal-Fire': 0.5,
#  'Normal-vs-Normal-Water': 1.0,
#  'Fighting-vs-Normal-Water': 2.0,
#  'Flying-vs-Normal-Water': 1.0,
#  'Poison-vs-Normal-Water': 1.0,
#  'Ground-vs-Normal-Water': 1.0,
#  'Rock-vs-Normal-Water': 1.0,
#  'Bug-vs-Normal-Water': 1.0,
#  'Ghost-vs-Normal-Water': 0.0,
#  'Steel-vs-Normal-Water': 0.5,
#  'Fire-vs-Normal-Water': 0.5,
#  'Water-vs-Normal-Water': 0.5,
#  'Grass-vs-Normal-Water': 2.0,
#  'Electric-vs-Normal-Water': 2.0,
#  'Psychic-vs-Normal-Water': 1.0,
#  'Ice-vs-Normal-Water': 0.5,
#  'Dragon-vs-Normal-Water': 1.0,
#  'Dark-vs-Normal-Water': 1.0,
#  'Fairy-vs-Normal-Water': 1.0,
#  'Normal-vs-Normal-Grass': 1.0,
#  'Fighting-vs-Normal-Grass': 2.0,
#  'Flying-vs-Normal-Grass': 2.0,
#  'Poison-vs-Normal-Grass': 2.0,
#  'Ground-vs-Normal-Grass': 0.5,
#  'Rock-vs-Normal-Grass': 1.0,
#  'Bug-vs-Normal-Grass': 2.0,
#  'Ghost-vs-Normal-Grass': 0.0,
#  'Steel-vs-Normal-Grass': 1.0,
#  'Fire-vs-Normal-Grass': 2.0,
#  'Water-vs-Normal-Grass': 0.5,
#  'Grass-vs-Normal-Grass': 0.5,
#  'Electric-vs-Normal-Grass': 0.5,
#  'Psychic-vs-Normal-Grass': 1.0,
#  'Ice-vs-Normal-Grass': 2.0,
#  'Dragon-vs-Normal-Grass': 1.0,
#  'Dark-vs-Normal-Grass': 1.0,
#  'Fairy-vs-Normal-Grass': 1.0,
#  'Normal-vs-Normal-Electric': 1.0,
#  'Fighting-vs-Normal-Electric': 2.0,
#  'Flying-vs-Normal-Electric': 0.5,
#  'Poison-vs-Normal-Electric': 1.0,
#  'Ground-vs-Normal-Electric': 2.0,
#  'Rock-vs-Normal-Electric': 1.0,
#  'Bug-vs-Normal-Electric': 1.0,
#  'Ghost-vs-Normal-Electric': 0.0,
#  'Steel-vs-Normal-Electric': 0.5,
#  'Fire-vs-Normal-Electric': 1.0,
#  'Water-vs-Normal-Electric': 1.0,
#  'Grass-vs-Normal-Electric': 1.0,
#  'Electric-vs-Normal-Electric': 0.5,
#  'Psychic-vs-Normal-Electric': 1.0,
#  'Ice-vs-Normal-Electric': 1.0,
#  'Dragon-vs-Normal-Electric': 1.0,
#  'Dark-vs-Normal-Electric': 1.0,
#  'Fairy-vs-Normal-Electric': 1.0,
#  'Normal-vs-Normal-Psychic': 1.0,
#  'Fighting-vs-Normal-Psychic': 1.0,
#  'Flying-vs-Normal-Psychic': 1.0,
#  'Poison-vs-Normal-Psychic': 1.0,
#  'Ground-vs-Normal-Psychic': 1.0,
#  'Rock-vs-Normal-Psychic': 1.0,
#  'Bug-vs-Normal-Psychic': 2.0,
#  'Ghost-vs-Normal-Psychic': 0.0,
#  'Steel-vs-Normal-Psychic': 1.0,
#  'Fire-vs-Normal-Psychic': 1.0,
#  'Water-vs-Normal-Psychic': 1.0,
#  'Grass-vs-Normal-Psychic': 1.0,
#  'Electric-vs-Normal-Psychic': 1.0,
#  'Psychic-vs-Normal-Psychic': 0.5,
#  'Ice-vs-Normal-Psychic': 1.0,
#  'Dragon-vs-Normal-Psychic': 1.0,
#  'Dark-vs-Normal-Psychic': 2.0,
#  'Fairy-vs-Normal-Psychic': 1.0,
#  'Normal-vs-Normal-Ice': 1.0,
#  'Fighting-vs-Normal-Ice': 4.0,
#  'Flying-vs-Normal-Ice': 1.0,
#  'Poison-vs-Normal-Ice': 1.0,
#  'Ground-vs-Normal-Ice': 1.0,
#  'Rock-vs-Normal-Ice': 2.0,
#  'Bug-vs-Normal-Ice': 1.0,
#  'Ghost-vs-Normal-Ice': 0.0,
#  'Steel-vs-Normal-Ice': 2.0,
#  'Fire-vs-Normal-Ice': 2.0,
#  'Water-vs-Normal-Ice': 1.0,
#  'Grass-vs-Normal-Ice': 1.0,
#  'Electric-vs-Normal-Ice': 1.0,
#  'Psychic-vs-Normal-Ice': 1.0,
#  'Ice-vs-Normal-Ice': 0.5,
#  'Dragon-vs-Normal-Ice': 1.0,
#  'Dark-vs-Normal-Ice': 1.0,
#  'Fairy-vs-Normal-Ice': 1.0,
#  'Normal-vs-Normal-Dragon': 1.0,
#  'Fighting-vs-Normal-Dragon': 2.0,
#  'Flying-vs-Normal-Dragon': 1.0,
#  'Poison-vs-Normal-Dragon': 1.0,
#  'Ground-vs-Normal-Dragon': 1.0,
#  'Rock-vs-Normal-Dragon': 1.0,
#  'Bug-vs-Normal-Dragon': 1.0,
#  'Ghost-vs-Normal-Dragon': 0.0,
#  'Steel-vs-Normal-Dragon': 1.0,
#  'Fire-vs-Normal-Dragon': 0.5,
#  'Water-vs-Normal-Dragon': 0.5,
#  'Grass-vs-Normal-Dragon': 0.5,
#  'Electric-vs-Normal-Dragon': 0.5,
#  'Psychic-vs-Normal-Dragon': 1.0,
#  'Ice-vs-Normal-Dragon': 2.0,
#  'Dragon-vs-Normal-Dragon': 2.0,
#  'Dark-vs-Normal-Dragon': 1.0,
#  'Fairy-vs-Normal-Dragon': 2.0,
#  'Normal-vs-Normal-Dark': 1.0,
#  'Fighting-vs-Normal-Dark': 4.0,
#  'Flying-vs-Normal-Dark': 1.0,
#  'Poison-vs-Normal-Dark': 1.0,
#  'Ground-vs-Normal-Dark': 1.0,
#  'Rock-vs-Normal-Dark': 1.0,
#  'Bug-vs-Normal-Dark': 2.0,
#  'Ghost-vs-Normal-Dark': 0.0,
#  'Steel-vs-Normal-Dark': 1.0,
#  'Fire-vs-Normal-Dark': 1.0,
#  'Water-vs-Normal-Dark': 1.0,
#  'Grass-vs-Normal-Dark': 1.0,
#  'Electric-vs-Normal-Dark': 1.0,
#  'Psychic-vs-Normal-Dark': 0.0,
#  'Ice-vs-Normal-Dark': 1.0,
#  'Dragon-vs-Normal-Dark': 1.0,
#  'Dark-vs-Normal-Dark': 0.5,
#  'Fairy-vs-Normal-Dark': 2.0,
#  'Normal-vs-Normal-Fairy': 1.0,
#  'Fighting-vs-Normal-Fairy': 1.0,
#  'Flying-vs-Normal-Fairy': 1.0,
#  'Poison-vs-Normal-Fairy': 2.0,
#  'Ground-vs-Normal-Fairy': 1.0,
#  'Rock-vs-Normal-Fairy': 1.0,
#  'Bug-vs-Normal-Fairy': 0.5,
#  'Ghost-vs-Normal-Fairy': 0.0,
#  'Steel-vs-Normal-Fairy': 2.0,
#  'Fire-vs-Normal-Fairy': 1.0,
#  'Water-vs-Normal-Fairy': 1.0,
#  'Grass-vs-Normal-Fairy': 1.0,
#  'Electric-vs-Normal-Fairy': 1.0,
#  'Psychic-vs-Normal-Fairy': 1.0,
#  'Ice-vs-Normal-Fairy': 1.0,
#  'Dragon-vs-Normal-Fairy': 0.0,
#  'Dark-vs-Normal-Fairy': 0.5,
#  'Fairy-vs-Normal-Fairy': 1.0,
#  'Normal-vs-Fighting-None': 1.0,
#  'Fighting-vs-Fighting-None': 1.0,
#  'Flying-vs-Fighting-None': 2.0,
#  'Poison-vs-Fighting-None': 1.0,
#  'Ground-vs-Fighting-None': 1.0,
#  'Rock-vs-Fighting-None': 0.5,
#  'Bug-vs-Fighting-None': 0.5,
#  'Ghost-vs-Fighting-None': 1.0,
#  'Steel-vs-Fighting-None': 1.0,
#  'Fire-vs-Fighting-None': 1.0,
#  'Water-vs-Fighting-None': 1.0,
#  'Grass-vs-Fighting-None': 1.0,
#  'Electric-vs-Fighting-None': 1.0,
#  'Psychic-vs-Fighting-None': 2.0,
#  'Ice-vs-Fighting-None': 1.0,
#  'Dragon-vs-Fighting-None': 1.0,
#  'Dark-vs-Fighting-None': 0.5,
#  'Fairy-vs-Fighting-None': 2.0,
#  'Normal-vs-Fighting-Normal': 1.0,
#  'Fighting-vs-Fighting-Normal': 2.0,
#  'Flying-vs-Fighting-Normal': 2.0,
#  'Poison-vs-Fighting-Normal': 1.0,
#  'Ground-vs-Fighting-Normal': 1.0,
#  'Rock-vs-Fighting-Normal': 0.5,
#  'Bug-vs-Fighting-Normal': 0.5,
#  'Ghost-vs-Fighting-Normal': 0.0,
#  'Steel-vs-Fighting-Normal': 1.0,
#  'Fire-vs-Fighting-Normal': 1.0,
#  'Water-vs-Fighting-Normal': 1.0,
#  'Grass-vs-Fighting-Normal': 1.0,
#  'Electric-vs-Fighting-Normal': 1.0,
#  'Psychic-vs-Fighting-Normal': 2.0,
#  'Ice-vs-Fighting-Normal': 1.0,
#  'Dragon-vs-Fighting-Normal': 1.0,
#  'Dark-vs-Fighting-Normal': 0.5,
#  'Fairy-vs-Fighting-Normal': 2.0,
#  'Normal-vs-Fighting-Fighting': 1.0,
#  'Fighting-vs-Fighting-Fighting': 1.0,
#  'Flying-vs-Fighting-Fighting': 4.0,
#  'Poison-vs-Fighting-Fighting': 1.0,
#  'Ground-vs-Fighting-Fighting': 1.0,
#  'Rock-vs-Fighting-Fighting': 0.25,
#  'Bug-vs-Fighting-Fighting': 0.25,
#  'Ghost-vs-Fighting-Fighting': 1.0,
#  'Steel-vs-Fighting-Fighting': 1.0,
#  'Fire-vs-Fighting-Fighting': 1.0,
#  'Water-vs-Fighting-Fighting': 1.0,
#  'Grass-vs-Fighting-Fighting': 1.0,
#  'Electric-vs-Fighting-Fighting': 1.0,
#  'Psychic-vs-Fighting-Fighting': 4.0,
#  'Ice-vs-Fighting-Fighting': 1.0,
#  'Dragon-vs-Fighting-Fighting': 1.0,
#  'Dark-vs-Fighting-Fighting': 0.25,
#  'Fairy-vs-Fighting-Fighting': 4.0,
#  'Normal-vs-Fighting-Flying': 1.0,
#  'Fighting-vs-Fighting-Flying': 0.5,
#  'Flying-vs-Fighting-Flying': 2.0,
#  'Poison-vs-Fighting-Flying': 1.0,
#  'Ground-vs-Fighting-Flying': 0.0,
#  'Rock-vs-Fighting-Flying': 1.0,
#  'Bug-vs-Fighting-Flying': 0.25,
#  'Ghost-vs-Fighting-Flying': 1.0,
#  'Steel-vs-Fighting-Flying': 1.0,
#  'Fire-vs-Fighting-Flying': 1.0,
#  'Water-vs-Fighting-Flying': 1.0,
#  'Grass-vs-Fighting-Flying': 0.5,
#  'Electric-vs-Fighting-Flying': 2.0,
#  'Psychic-vs-Fighting-Flying': 2.0,
#  'Ice-vs-Fighting-Flying': 2.0,
#  'Dragon-vs-Fighting-Flying': 1.0,
#  'Dark-vs-Fighting-Flying': 0.5,
#  'Fairy-vs-Fighting-Flying': 2.0,
#  'Normal-vs-Fighting-Poison': 1.0,
#  'Fighting-vs-Fighting-Poison': 0.5,
#  'Flying-vs-Fighting-Poison': 2.0,
#  'Poison-vs-Fighting-Poison': 0.5,
#  'Ground-vs-Fighting-Poison': 2.0,
#  'Rock-vs-Fighting-Poison': 0.5,
#  'Bug-vs-Fighting-Poison': 0.25,
#  'Ghost-vs-Fighting-Poison': 1.0,
#  'Steel-vs-Fighting-Poison': 1.0,
#  'Fire-vs-Fighting-Poison': 1.0,
#  'Water-vs-Fighting-Poison': 1.0,
#  'Grass-vs-Fighting-Poison': 0.5,
#  'Electric-vs-Fighting-Poison': 1.0,
#  'Psychic-vs-Fighting-Poison': 4.0,
#  'Ice-vs-Fighting-Poison': 1.0,
#  'Dragon-vs-Fighting-Poison': 1.0,
#  'Dark-vs-Fighting-Poison': 0.5,
#  'Fairy-vs-Fighting-Poison': 1.0,
#  'Normal-vs-Fighting-Ground': 1.0,
#  'Fighting-vs-Fighting-Ground': 1.0,
#  'Flying-vs-Fighting-Ground': 2.0,
#  'Poison-vs-Fighting-Ground': 0.5,
#  'Ground-vs-Fighting-Ground': 1.0,
#  'Rock-vs-Fighting-Ground': 0.25,
#  'Bug-vs-Fighting-Ground': 0.5,
#  'Ghost-vs-Fighting-Ground': 1.0,
#  'Steel-vs-Fighting-Ground': 1.0,
#  'Fire-vs-Fighting-Ground': 1.0,
#  'Water-vs-Fighting-Ground': 2.0,
#  'Grass-vs-Fighting-Ground': 2.0,
#  'Electric-vs-Fighting-Ground': 0.0,
#  'Psychic-vs-Fighting-Ground': 2.0,
#  'Ice-vs-Fighting-Ground': 2.0,
#  'Dragon-vs-Fighting-Ground': 1.0,
#  'Dark-vs-Fighting-Ground': 0.5,
#  'Fairy-vs-Fighting-Ground': 2.0,
#  'Normal-vs-Fighting-Rock': 0.5,
#  'Fighting-vs-Fighting-Rock': 2.0,
#  'Flying-vs-Fighting-Rock': 1.0,
#  'Poison-vs-Fighting-Rock': 0.5,
#  'Ground-vs-Fighting-Rock': 2.0,
#  'Rock-vs-Fighting-Rock': 0.5,
#  'Bug-vs-Fighting-Rock': 0.5,
#  'Ghost-vs-Fighting-Rock': 1.0,
#  'Steel-vs-Fighting-Rock': 2.0,
#  'Fire-vs-Fighting-Rock': 0.5,
#  'Water-vs-Fighting-Rock': 2.0,
#  'Grass-vs-Fighting-Rock': 2.0,
#  'Electric-vs-Fighting-Rock': 1.0,
#  'Psychic-vs-Fighting-Rock': 2.0,
#  'Ice-vs-Fighting-Rock': 1.0,
#  'Dragon-vs-Fighting-Rock': 1.0,
#  'Dark-vs-Fighting-Rock': 0.5,
#  'Fairy-vs-Fighting-Rock': 2.0,
#  'Normal-vs-Fighting-Bug': 1.0,
#  'Fighting-vs-Fighting-Bug': 0.5,
#  'Flying-vs-Fighting-Bug': 4.0,
#  'Poison-vs-Fighting-Bug': 1.0,
#  'Ground-vs-Fighting-Bug': 0.5,
#  'Rock-vs-Fighting-Bug': 1.0,
#  'Bug-vs-Fighting-Bug': 0.5,
#  'Ghost-vs-Fighting-Bug': 1.0,
#  'Steel-vs-Fighting-Bug': 1.0,
#  'Fire-vs-Fighting-Bug': 2.0,
#  'Water-vs-Fighting-Bug': 1.0,
#  'Grass-vs-Fighting-Bug': 0.5,
#  'Electric-vs-Fighting-Bug': 1.0,
#  'Psychic-vs-Fighting-Bug': 2.0,
#  'Ice-vs-Fighting-Bug': 1.0,
#  'Dragon-vs-Fighting-Bug': 1.0,
#  'Dark-vs-Fighting-Bug': 0.5,
#  'Fairy-vs-Fighting-Bug': 2.0,
#  'Normal-vs-Fighting-Ghost': 0.0,
#  'Fighting-vs-Fighting-Ghost': 0.0,
#  'Flying-vs-Fighting-Ghost': 2.0,
#  'Poison-vs-Fighting-Ghost': 0.5,
#  'Ground-vs-Fighting-Ghost': 1.0,
#  'Rock-vs-Fighting-Ghost': 0.5,
#  'Bug-vs-Fighting-Ghost': 0.25,
#  'Ghost-vs-Fighting-Ghost': 2.0,
#  'Steel-vs-Fighting-Ghost': 1.0,
#  'Fire-vs-Fighting-Ghost': 1.0,
#  'Water-vs-Fighting-Ghost': 1.0,
#  'Grass-vs-Fighting-Ghost': 1.0,
#  'Electric-vs-Fighting-Ghost': 1.0,
#  'Psychic-vs-Fighting-Ghost': 2.0,
#  'Ice-vs-Fighting-Ghost': 1.0,
#  'Dragon-vs-Fighting-Ghost': 1.0,
#  'Dark-vs-Fighting-Ghost': 1.0,
#  'Fairy-vs-Fighting-Ghost': 2.0,
#  'Normal-vs-Fighting-Steel': 0.5,
#  'Fighting-vs-Fighting-Steel': 2.0,
#  'Flying-vs-Fighting-Steel': 1.0,
#  'Poison-vs-Fighting-Steel': 0.0,
#  'Ground-vs-Fighting-Steel': 2.0,
#  'Rock-vs-Fighting-Steel': 0.25,
#  'Bug-vs-Fighting-Steel': 0.25,
#  'Ghost-vs-Fighting-Steel': 1.0,
#  'Steel-vs-Fighting-Steel': 0.5,
#  'Fire-vs-Fighting-Steel': 2.0,
#  'Water-vs-Fighting-Steel': 1.0,
#  'Grass-vs-Fighting-Steel': 0.5,
#  'Electric-vs-Fighting-Steel': 1.0,
#  'Psychic-vs-Fighting-Steel': 1.0,
#  'Ice-vs-Fighting-Steel': 0.5,
#  'Dragon-vs-Fighting-Steel': 0.5,
#  'Dark-vs-Fighting-Steel': 0.5,
#  'Fairy-vs-Fighting-Steel': 1.0,
#  'Normal-vs-Fighting-Fire': 1.0,
#  'Fighting-vs-Fighting-Fire': 1.0,
#  'Flying-vs-Fighting-Fire': 2.0,
#  'Poison-vs-Fighting-Fire': 1.0,
#  'Ground-vs-Fighting-Fire': 2.0,
#  'Rock-vs-Fighting-Fire': 1.0,
#  'Bug-vs-Fighting-Fire': 0.25,
#  'Ghost-vs-Fighting-Fire': 1.0,
#  'Steel-vs-Fighting-Fire': 0.5,
#  'Fire-vs-Fighting-Fire': 0.5,
#  'Water-vs-Fighting-Fire': 2.0,
#  'Grass-vs-Fighting-Fire': 0.5,
#  'Electric-vs-Fighting-Fire': 1.0,
#  'Psychic-vs-Fighting-Fire': 2.0,
#  'Ice-vs-Fighting-Fire': 0.5,
#  'Dragon-vs-Fighting-Fire': 1.0,
#  'Dark-vs-Fighting-Fire': 0.5,
#  'Fairy-vs-Fighting-Fire': 1.0,
#  'Normal-vs-Fighting-Water': 1.0,
#  'Fighting-vs-Fighting-Water': 1.0,
#  'Flying-vs-Fighting-Water': 2.0,
#  'Poison-vs-Fighting-Water': 1.0,
#  'Ground-vs-Fighting-Water': 1.0,
#  'Rock-vs-Fighting-Water': 0.5,
#  'Bug-vs-Fighting-Water': 0.5,
#  'Ghost-vs-Fighting-Water': 1.0,
#  'Steel-vs-Fighting-Water': 0.5,
#  'Fire-vs-Fighting-Water': 0.5,
#  'Water-vs-Fighting-Water': 0.5,
#  'Grass-vs-Fighting-Water': 2.0,
#  'Electric-vs-Fighting-Water': 2.0,
#  'Psychic-vs-Fighting-Water': 2.0,
#  'Ice-vs-Fighting-Water': 0.5,
#  'Dragon-vs-Fighting-Water': 1.0,
#  'Dark-vs-Fighting-Water': 0.5,
#  'Fairy-vs-Fighting-Water': 2.0,
#  'Normal-vs-Fighting-Grass': 1.0,
#  'Fighting-vs-Fighting-Grass': 1.0,
#  'Flying-vs-Fighting-Grass': 4.0,
#  'Poison-vs-Fighting-Grass': 2.0,
#  'Ground-vs-Fighting-Grass': 0.5,
#  'Rock-vs-Fighting-Grass': 0.5,
#  'Bug-vs-Fighting-Grass': 1.0,
#  'Ghost-vs-Fighting-Grass': 1.0,
#  'Steel-vs-Fighting-Grass': 1.0,
#  'Fire-vs-Fighting-Grass': 2.0,
#  'Water-vs-Fighting-Grass': 0.5,
#  'Grass-vs-Fighting-Grass': 0.5,
#  'Electric-vs-Fighting-Grass': 0.5,
#  'Psychic-vs-Fighting-Grass': 2.0,
#  'Ice-vs-Fighting-Grass': 2.0,
#  'Dragon-vs-Fighting-Grass': 1.0,
#  'Dark-vs-Fighting-Grass': 0.5,
#  'Fairy-vs-Fighting-Grass': 2.0,
#  'Normal-vs-Fighting-Electric': 1.0,
#  'Fighting-vs-Fighting-Electric': 1.0,
#  'Flying-vs-Fighting-Electric': 1.0,
#  'Poison-vs-Fighting-Electric': 1.0,
#  'Ground-vs-Fighting-Electric': 2.0,
#  'Rock-vs-Fighting-Electric': 0.5,
#  'Bug-vs-Fighting-Electric': 0.5,
#  'Ghost-vs-Fighting-Electric': 1.0,
#  'Steel-vs-Fighting-Electric': 0.5,
#  'Fire-vs-Fighting-Electric': 1.0,
#  'Water-vs-Fighting-Electric': 1.0,
#  'Grass-vs-Fighting-Electric': 1.0,
#  'Electric-vs-Fighting-Electric': 0.5,
#  'Psychic-vs-Fighting-Electric': 2.0,
#  'Ice-vs-Fighting-Electric': 1.0,
#  'Dragon-vs-Fighting-Electric': 1.0,
#  'Dark-vs-Fighting-Electric': 0.5,
#  'Fairy-vs-Fighting-Electric': 2.0,
#  'Normal-vs-Fighting-Psychic': 1.0,
#  'Fighting-vs-Fighting-Psychic': 0.5,
#  'Flying-vs-Fighting-Psychic': 2.0,
#  'Poison-vs-Fighting-Psychic': 1.0,
#  'Ground-vs-Fighting-Psychic': 1.0,
#  'Rock-vs-Fighting-Psychic': 0.5,
#  'Bug-vs-Fighting-Psychic': 1.0,
#  'Ghost-vs-Fighting-Psychic': 2.0,
#  'Steel-vs-Fighting-Psychic': 1.0,
#  'Fire-vs-Fighting-Psychic': 1.0,
#  'Water-vs-Fighting-Psychic': 1.0,
#  'Grass-vs-Fighting-Psychic': 1.0,
#  'Electric-vs-Fighting-Psychic': 1.0,
#  'Psychic-vs-Fighting-Psychic': 1.0,
#  'Ice-vs-Fighting-Psychic': 1.0,
#  'Dragon-vs-Fighting-Psychic': 1.0,
#  'Dark-vs-Fighting-Psychic': 1.0,
#  'Fairy-vs-Fighting-Psychic': 2.0,
#  'Normal-vs-Fighting-Ice': 1.0,
#  'Fighting-vs-Fighting-Ice': 2.0,
#  'Flying-vs-Fighting-Ice': 2.0,
#  'Poison-vs-Fighting-Ice': 1.0,
#  'Ground-vs-Fighting-Ice': 1.0,
#  'Rock-vs-Fighting-Ice': 1.0,
#  'Bug-vs-Fighting-Ice': 0.5,
#  'Ghost-vs-Fighting-Ice': 1.0,
#  'Steel-vs-Fighting-Ice': 2.0,
#  'Fire-vs-Fighting-Ice': 2.0,
#  'Water-vs-Fighting-Ice': 1.0,
#  'Grass-vs-Fighting-Ice': 1.0,
#  'Electric-vs-Fighting-Ice': 1.0,
#  'Psychic-vs-Fighting-Ice': 2.0,
#  'Ice-vs-Fighting-Ice': 0.5,
#  'Dragon-vs-Fighting-Ice': 1.0,
#  'Dark-vs-Fighting-Ice': 0.5,
#  'Fairy-vs-Fighting-Ice': 2.0,
#  'Normal-vs-Fighting-Dragon': 1.0,
#  'Fighting-vs-Fighting-Dragon': 1.0,
#  'Flying-vs-Fighting-Dragon': 2.0,
#  'Poison-vs-Fighting-Dragon': 1.0,
#  'Ground-vs-Fighting-Dragon': 1.0,
#  'Rock-vs-Fighting-Dragon': 0.5,
#  'Bug-vs-Fighting-Dragon': 0.5,
#  'Ghost-vs-Fighting-Dragon': 1.0,
#  'Steel-vs-Fighting-Dragon': 1.0,
#  'Fire-vs-Fighting-Dragon': 0.5,
#  'Water-vs-Fighting-Dragon': 0.5,
#  'Grass-vs-Fighting-Dragon': 0.5,
#  'Electric-vs-Fighting-Dragon': 0.5,
#  'Psychic-vs-Fighting-Dragon': 2.0,
#  'Ice-vs-Fighting-Dragon': 2.0,
#  'Dragon-vs-Fighting-Dragon': 2.0,
#  'Dark-vs-Fighting-Dragon': 0.5,
#  'Fairy-vs-Fighting-Dragon': 4.0,
#  'Normal-vs-Fighting-Dark': 1.0,
#  'Fighting-vs-Fighting-Dark': 2.0,
#  'Flying-vs-Fighting-Dark': 2.0,
#  'Poison-vs-Fighting-Dark': 1.0,
#  'Ground-vs-Fighting-Dark': 1.0,
#  'Rock-vs-Fighting-Dark': 0.5,
#  'Bug-vs-Fighting-Dark': 1.0,
#  'Ghost-vs-Fighting-Dark': 0.5,
#  'Steel-vs-Fighting-Dark': 1.0,
#  'Fire-vs-Fighting-Dark': 1.0,
#  'Water-vs-Fighting-Dark': 1.0,
#  'Grass-vs-Fighting-Dark': 1.0,
#  'Electric-vs-Fighting-Dark': 1.0,
#  'Psychic-vs-Fighting-Dark': 0.0,
#  'Ice-vs-Fighting-Dark': 1.0,
#  'Dragon-vs-Fighting-Dark': 1.0,
#  'Dark-vs-Fighting-Dark': 0.25,
#  'Fairy-vs-Fighting-Dark': 4.0,
#  'Normal-vs-Fighting-Fairy': 1.0,
#  'Fighting-vs-Fighting-Fairy': 0.5,
#  'Flying-vs-Fighting-Fairy': 2.0,
#  'Poison-vs-Fighting-Fairy': 2.0,
#  'Ground-vs-Fighting-Fairy': 1.0,
#  'Rock-vs-Fighting-Fairy': 0.5,
#  'Bug-vs-Fighting-Fairy': 0.25,
#  'Ghost-vs-Fighting-Fairy': 1.0,
#  'Steel-vs-Fighting-Fairy': 2.0,
#  'Fire-vs-Fighting-Fairy': 1.0,
#  'Water-vs-Fighting-Fairy': 1.0,
#  'Grass-vs-Fighting-Fairy': 1.0,
#  'Electric-vs-Fighting-Fairy': 1.0,
#  'Psychic-vs-Fighting-Fairy': 2.0,
#  'Ice-vs-Fighting-Fairy': 1.0,
#  'Dragon-vs-Fighting-Fairy': 0.0,
#  'Dark-vs-Fighting-Fairy': 0.25,
#  'Fairy-vs-Fighting-Fairy': 2.0,
#  'Normal-vs-Flying-None': 1.0,
#  'Fighting-vs-Flying-None': 0.5,
#  'Flying-vs-Flying-None': 1.0,
#  'Poison-vs-Flying-None': 1.0,
#  'Ground-vs-Flying-None': 0.0,
#  'Rock-vs-Flying-None': 2.0,
#  'Bug-vs-Flying-None': 0.5,
#  'Ghost-vs-Flying-None': 1.0,
#  'Steel-vs-Flying-None': 1.0,
#  'Fire-vs-Flying-None': 1.0,
#  'Water-vs-Flying-None': 1.0,
#  'Grass-vs-Flying-None': 0.5,
#  'Electric-vs-Flying-None': 2.0,
#  'Psychic-vs-Flying-None': 1.0,
#  'Ice-vs-Flying-None': 2.0,
#  'Dragon-vs-Flying-None': 1.0,
#  'Dark-vs-Flying-None': 1.0,
#  'Fairy-vs-Flying-None': 1.0,
#  'Normal-vs-Flying-Normal': 1.0,
#  'Fighting-vs-Flying-Normal': 1.0,
#  'Flying-vs-Flying-Normal': 1.0,
#  'Poison-vs-Flying-Normal': 1.0,
#  'Ground-vs-Flying-Normal': 0.0,
#  'Rock-vs-Flying-Normal': 2.0,
#  'Bug-vs-Flying-Normal': 0.5,
#  'Ghost-vs-Flying-Normal': 0.0,
#  'Steel-vs-Flying-Normal': 1.0,
#  'Fire-vs-Flying-Normal': 1.0,
#  'Water-vs-Flying-Normal': 1.0,
#  'Grass-vs-Flying-Normal': 0.5,
#  'Electric-vs-Flying-Normal': 2.0,
#  'Psychic-vs-Flying-Normal': 1.0,
#  'Ice-vs-Flying-Normal': 2.0,
#  'Dragon-vs-Flying-Normal': 1.0,
#  'Dark-vs-Flying-Normal': 1.0,
#  'Fairy-vs-Flying-Normal': 1.0,
#  'Normal-vs-Flying-Fighting': 1.0,
#  'Fighting-vs-Flying-Fighting': 0.5,
#  'Flying-vs-Flying-Fighting': 2.0,
#  'Poison-vs-Flying-Fighting': 1.0,
#  'Ground-vs-Flying-Fighting': 0.0,
#  'Rock-vs-Flying-Fighting': 1.0,
#  'Bug-vs-Flying-Fighting': 0.25,
#  'Ghost-vs-Flying-Fighting': 1.0,
#  'Steel-vs-Flying-Fighting': 1.0,
#  'Fire-vs-Flying-Fighting': 1.0,
#  'Water-vs-Flying-Fighting': 1.0,
#  'Grass-vs-Flying-Fighting': 0.5,
#  'Electric-vs-Flying-Fighting': 2.0,
#  'Psychic-vs-Flying-Fighting': 2.0,
#  'Ice-vs-Flying-Fighting': 2.0,
#  'Dragon-vs-Flying-Fighting': 1.0,
#  'Dark-vs-Flying-Fighting': 0.5,
#  'Fairy-vs-Flying-Fighting': 2.0,
#  'Normal-vs-Flying-Flying': 1.0,
#  'Fighting-vs-Flying-Flying': 0.25,
#  'Flying-vs-Flying-Flying': 1.0,
#  'Poison-vs-Flying-Flying': 1.0,
#  'Ground-vs-Flying-Flying': 0.0,
#  'Rock-vs-Flying-Flying': 4.0,
#  'Bug-vs-Flying-Flying': 0.25,
#  'Ghost-vs-Flying-Flying': 1.0,
#  'Steel-vs-Flying-Flying': 1.0,
#  'Fire-vs-Flying-Flying': 1.0,
#  'Water-vs-Flying-Flying': 1.0,
#  'Grass-vs-Flying-Flying': 0.25,
#  'Electric-vs-Flying-Flying': 4.0,
#  'Psychic-vs-Flying-Flying': 1.0,
#  'Ice-vs-Flying-Flying': 4.0,
#  'Dragon-vs-Flying-Flying': 1.0,
#  'Dark-vs-Flying-Flying': 1.0,
#  'Fairy-vs-Flying-Flying': 1.0,
#  'Normal-vs-Flying-Poison': 1.0,
#  'Fighting-vs-Flying-Poison': 0.25,
#  'Flying-vs-Flying-Poison': 1.0,
#  'Poison-vs-Flying-Poison': 0.5,
#  'Ground-vs-Flying-Poison': 0.0,
#  'Rock-vs-Flying-Poison': 2.0,
#  'Bug-vs-Flying-Poison': 0.25,
#  'Ghost-vs-Flying-Poison': 1.0,
#  'Steel-vs-Flying-Poison': 1.0,
#  'Fire-vs-Flying-Poison': 1.0,
#  'Water-vs-Flying-Poison': 1.0,
#  'Grass-vs-Flying-Poison': 0.25,
#  'Electric-vs-Flying-Poison': 2.0,
#  'Psychic-vs-Flying-Poison': 2.0,
#  'Ice-vs-Flying-Poison': 2.0,
#  'Dragon-vs-Flying-Poison': 1.0,
#  'Dark-vs-Flying-Poison': 1.0,
#  'Fairy-vs-Flying-Poison': 0.5,
#  'Normal-vs-Flying-Ground': 1.0,
#  'Fighting-vs-Flying-Ground': 0.5,
#  'Flying-vs-Flying-Ground': 1.0,
#  'Poison-vs-Flying-Ground': 0.5,
#  'Ground-vs-Flying-Ground': 0.0,
#  'Rock-vs-Flying-Ground': 1.0,
#  'Bug-vs-Flying-Ground': 0.5,
#  'Ghost-vs-Flying-Ground': 1.0,
#  'Steel-vs-Flying-Ground': 1.0,
#  'Fire-vs-Flying-Ground': 1.0,
#  'Water-vs-Flying-Ground': 2.0,
#  'Grass-vs-Flying-Ground': 1.0,
#  'Electric-vs-Flying-Ground': 0.0,
#  'Psychic-vs-Flying-Ground': 1.0,
#  'Ice-vs-Flying-Ground': 4.0,
#  'Dragon-vs-Flying-Ground': 1.0,
#  'Dark-vs-Flying-Ground': 1.0,
#  'Fairy-vs-Flying-Ground': 1.0,
#  'Normal-vs-Flying-Rock': 0.5,
#  'Fighting-vs-Flying-Rock': 1.0,
#  'Flying-vs-Flying-Rock': 0.5,
#  'Poison-vs-Flying-Rock': 0.5,
#  'Ground-vs-Flying-Rock': 0.0,
#  'Rock-vs-Flying-Rock': 2.0,
#  'Bug-vs-Flying-Rock': 0.5,
#  'Ghost-vs-Flying-Rock': 1.0,
#  'Steel-vs-Flying-Rock': 2.0,
#  'Fire-vs-Flying-Rock': 0.5,
#  'Water-vs-Flying-Rock': 2.0,
#  'Grass-vs-Flying-Rock': 1.0,
#  'Electric-vs-Flying-Rock': 2.0,
#  'Psychic-vs-Flying-Rock': 1.0,
#  'Ice-vs-Flying-Rock': 2.0,
#  'Dragon-vs-Flying-Rock': 1.0,
#  'Dark-vs-Flying-Rock': 1.0,
#  'Fairy-vs-Flying-Rock': 1.0,
#  'Normal-vs-Flying-Bug': 1.0,
#  'Fighting-vs-Flying-Bug': 0.25,
#  'Flying-vs-Flying-Bug': 2.0,
#  'Poison-vs-Flying-Bug': 1.0,
#  'Ground-vs-Flying-Bug': 0.0,
#  'Rock-vs-Flying-Bug': 4.0,
#  'Bug-vs-Flying-Bug': 0.5,
#  'Ghost-vs-Flying-Bug': 1.0,
#  'Steel-vs-Flying-Bug': 1.0,
#  'Fire-vs-Flying-Bug': 2.0,
#  'Water-vs-Flying-Bug': 1.0,
#  'Grass-vs-Flying-Bug': 0.25,
#  'Electric-vs-Flying-Bug': 2.0,
#  'Psychic-vs-Flying-Bug': 1.0,
#  'Ice-vs-Flying-Bug': 2.0,
#  'Dragon-vs-Flying-Bug': 1.0,
#  'Dark-vs-Flying-Bug': 1.0,
#  'Fairy-vs-Flying-Bug': 1.0,
#  'Normal-vs-Flying-Ghost': 0.0,
#  'Fighting-vs-Flying-Ghost': 0.0,
#  'Flying-vs-Flying-Ghost': 1.0,
#  'Poison-vs-Flying-Ghost': 0.5,
#  'Ground-vs-Flying-Ghost': 0.0,
#  'Rock-vs-Flying-Ghost': 2.0,
#  'Bug-vs-Flying-Ghost': 0.25,
#  'Ghost-vs-Flying-Ghost': 2.0,
#  'Steel-vs-Flying-Ghost': 1.0,
#  'Fire-vs-Flying-Ghost': 1.0,
#  'Water-vs-Flying-Ghost': 1.0,
#  'Grass-vs-Flying-Ghost': 0.5,
#  'Electric-vs-Flying-Ghost': 2.0,
#  'Psychic-vs-Flying-Ghost': 1.0,
#  'Ice-vs-Flying-Ghost': 2.0,
#  'Dragon-vs-Flying-Ghost': 1.0,
#  'Dark-vs-Flying-Ghost': 2.0,
#  'Fairy-vs-Flying-Ghost': 1.0,
#  'Normal-vs-Flying-Steel': 0.5,
#  'Fighting-vs-Flying-Steel': 1.0,
#  'Flying-vs-Flying-Steel': 0.5,
#  'Poison-vs-Flying-Steel': 0.0,
#  'Ground-vs-Flying-Steel': 0.0,
#  'Rock-vs-Flying-Steel': 1.0,
#  'Bug-vs-Flying-Steel': 0.25,
#  'Ghost-vs-Flying-Steel': 1.0,
#  'Steel-vs-Flying-Steel': 0.5,
#  'Fire-vs-Flying-Steel': 2.0,
#  'Water-vs-Flying-Steel': 1.0,
#  'Grass-vs-Flying-Steel': 0.25,
#  'Electric-vs-Flying-Steel': 2.0,
#  'Psychic-vs-Flying-Steel': 0.5,
#  'Ice-vs-Flying-Steel': 1.0,
#  'Dragon-vs-Flying-Steel': 0.5,
#  'Dark-vs-Flying-Steel': 1.0,
#  'Fairy-vs-Flying-Steel': 0.5,
#  'Normal-vs-Flying-Fire': 1.0,
#  'Fighting-vs-Flying-Fire': 0.5,
#  'Flying-vs-Flying-Fire': 1.0,
#  'Poison-vs-Flying-Fire': 1.0,
#  'Ground-vs-Flying-Fire': 0.0,
#  'Rock-vs-Flying-Fire': 4.0,
#  'Bug-vs-Flying-Fire': 0.25,
#  'Ghost-vs-Flying-Fire': 1.0,
#  'Steel-vs-Flying-Fire': 0.5,
#  'Fire-vs-Flying-Fire': 0.5,
#  'Water-vs-Flying-Fire': 2.0,
#  'Grass-vs-Flying-Fire': 0.25,
#  'Electric-vs-Flying-Fire': 2.0,
#  'Psychic-vs-Flying-Fire': 1.0,
#  'Ice-vs-Flying-Fire': 1.0,
#  'Dragon-vs-Flying-Fire': 1.0,
#  'Dark-vs-Flying-Fire': 1.0,
#  'Fairy-vs-Flying-Fire': 0.5,
#  'Normal-vs-Flying-Water': 1.0,
#  'Fighting-vs-Flying-Water': 0.5,
#  'Flying-vs-Flying-Water': 1.0,
#  'Poison-vs-Flying-Water': 1.0,
#  'Ground-vs-Flying-Water': 0.0,
#  'Rock-vs-Flying-Water': 2.0,
#  'Bug-vs-Flying-Water': 0.5,
#  'Ghost-vs-Flying-Water': 1.0,
#  'Steel-vs-Flying-Water': 0.5,
#  'Fire-vs-Flying-Water': 0.5,
#  'Water-vs-Flying-Water': 0.5,
#  'Grass-vs-Flying-Water': 1.0,
#  'Electric-vs-Flying-Water': 4.0,
#  'Psychic-vs-Flying-Water': 1.0,
#  'Ice-vs-Flying-Water': 1.0,
#  'Dragon-vs-Flying-Water': 1.0,
#  'Dark-vs-Flying-Water': 1.0,
#  'Fairy-vs-Flying-Water': 1.0,
#  'Normal-vs-Flying-Grass': 1.0,
#  'Fighting-vs-Flying-Grass': 0.5,
#  'Flying-vs-Flying-Grass': 2.0,
#  'Poison-vs-Flying-Grass': 2.0,
#  'Ground-vs-Flying-Grass': 0.0,
#  'Rock-vs-Flying-Grass': 2.0,
#  'Bug-vs-Flying-Grass': 1.0,
#  'Ghost-vs-Flying-Grass': 1.0,
#  'Steel-vs-Flying-Grass': 1.0,
#  'Fire-vs-Flying-Grass': 2.0,
#  'Water-vs-Flying-Grass': 0.5,
#  'Grass-vs-Flying-Grass': 0.25,
#  'Electric-vs-Flying-Grass': 1.0,
#  'Psychic-vs-Flying-Grass': 1.0,
#  'Ice-vs-Flying-Grass': 4.0,
#  'Dragon-vs-Flying-Grass': 1.0,
#  'Dark-vs-Flying-Grass': 1.0,
#  'Fairy-vs-Flying-Grass': 1.0,
#  'Normal-vs-Flying-Electric': 1.0,
#  'Fighting-vs-Flying-Electric': 0.5,
#  'Flying-vs-Flying-Electric': 0.5,
#  'Poison-vs-Flying-Electric': 1.0,
#  'Ground-vs-Flying-Electric': 0.0,
#  'Rock-vs-Flying-Electric': 2.0,
#  'Bug-vs-Flying-Electric': 0.5,
#  'Ghost-vs-Flying-Electric': 1.0,
#  'Steel-vs-Flying-Electric': 0.5,
#  'Fire-vs-Flying-Electric': 1.0,
#  'Water-vs-Flying-Electric': 1.0,
#  'Grass-vs-Flying-Electric': 0.5,
#  'Electric-vs-Flying-Electric': 1.0,
#  'Psychic-vs-Flying-Electric': 1.0,
#  'Ice-vs-Flying-Electric': 2.0,
#  'Dragon-vs-Flying-Electric': 1.0,
#  'Dark-vs-Flying-Electric': 1.0,
#  'Fairy-vs-Flying-Electric': 1.0,
#  'Normal-vs-Flying-Psychic': 1.0,
#  'Fighting-vs-Flying-Psychic': 0.25,
#  'Flying-vs-Flying-Psychic': 1.0,
#  'Poison-vs-Flying-Psychic': 1.0,
#  'Ground-vs-Flying-Psychic': 0.0,
#  'Rock-vs-Flying-Psychic': 2.0,
#  'Bug-vs-Flying-Psychic': 1.0,
#  'Ghost-vs-Flying-Psychic': 2.0,
#  'Steel-vs-Flying-Psychic': 1.0,
#  'Fire-vs-Flying-Psychic': 1.0,
#  'Water-vs-Flying-Psychic': 1.0,
#  'Grass-vs-Flying-Psychic': 0.5,
#  'Electric-vs-Flying-Psychic': 2.0,
#  'Psychic-vs-Flying-Psychic': 0.5,
#  'Ice-vs-Flying-Psychic': 2.0,
#  'Dragon-vs-Flying-Psychic': 1.0,
#  'Dark-vs-Flying-Psychic': 2.0,
#  'Fairy-vs-Flying-Psychic': 1.0,
#  'Normal-vs-Flying-Ice': 1.0,
#  'Fighting-vs-Flying-Ice': 1.0,
#  'Flying-vs-Flying-Ice': 1.0,
#  'Poison-vs-Flying-Ice': 1.0,
#  'Ground-vs-Flying-Ice': 0.0,
#  'Rock-vs-Flying-Ice': 4.0,
#  'Bug-vs-Flying-Ice': 0.5,
#  'Ghost-vs-Flying-Ice': 1.0,
#  'Steel-vs-Flying-Ice': 2.0,
#  'Fire-vs-Flying-Ice': 2.0,
#  'Water-vs-Flying-Ice': 1.0,
#  'Grass-vs-Flying-Ice': 0.5,
#  'Electric-vs-Flying-Ice': 2.0,
#  'Psychic-vs-Flying-Ice': 1.0,
#  'Ice-vs-Flying-Ice': 1.0,
#  'Dragon-vs-Flying-Ice': 1.0,
#  'Dark-vs-Flying-Ice': 1.0,
#  'Fairy-vs-Flying-Ice': 1.0,
#  'Normal-vs-Flying-Dragon': 1.0,
#  'Fighting-vs-Flying-Dragon': 0.5,
#  'Flying-vs-Flying-Dragon': 1.0,
#  'Poison-vs-Flying-Dragon': 1.0,
#  'Ground-vs-Flying-Dragon': 0.0,
#  'Rock-vs-Flying-Dragon': 2.0,
#  'Bug-vs-Flying-Dragon': 0.5,
#  'Ghost-vs-Flying-Dragon': 1.0,
#  'Steel-vs-Flying-Dragon': 1.0,
#  'Fire-vs-Flying-Dragon': 0.5,
#  'Water-vs-Flying-Dragon': 0.5,
#  'Grass-vs-Flying-Dragon': 0.25,
#  'Electric-vs-Flying-Dragon': 1.0,
#  'Psychic-vs-Flying-Dragon': 1.0,
#  'Ice-vs-Flying-Dragon': 4.0,
#  'Dragon-vs-Flying-Dragon': 2.0,
#  'Dark-vs-Flying-Dragon': 1.0,
#  'Fairy-vs-Flying-Dragon': 2.0,
#  'Normal-vs-Flying-Dark': 1.0,
#  'Fighting-vs-Flying-Dark': 1.0,
#  'Flying-vs-Flying-Dark': 1.0,
#  'Poison-vs-Flying-Dark': 1.0,
#  'Ground-vs-Flying-Dark': 0.0,
#  'Rock-vs-Flying-Dark': 2.0,
#  'Bug-vs-Flying-Dark': 1.0,
#  'Ghost-vs-Flying-Dark': 0.5,
#  'Steel-vs-Flying-Dark': 1.0,
#  'Fire-vs-Flying-Dark': 1.0,
#  ...}

# %%
# Merge between battles & pokemon, also calculate types effectivity values
def merge_data(battles):
    
    battles = battles \
        .merge(pokemon.rename(lambda x: "f_%s" % x, axis="columns"), left_on="first_pokemon", right_on="f_#") \
        .merge(pokemon.rename(lambda x: "s_%s" % x, axis="columns"), left_on="second_pokemon", right_on="s_#") \

    battles["f_t1"] = (battles["f_type_1"] + "-vs-" + battles["s_type_1"] + "-" + battles["s_type_2"]).map(multiplier)
    battles["f_t2"] = (battles["f_type_2"] + "-vs-" + battles["s_type_1"] + "-" + battles["s_type_2"]).map(multiplier)
    battles["s_t1"] = (battles["s_type_1"] + "-vs-" + battles["f_type_1"] + "-" + battles["f_type_2"]).map(multiplier)
    battles["s_t2"] = (battles["s_type_2"] + "-vs-" + battles["f_type_1"] + "-" + battles["f_type_2"]).map(multiplier)
    
    battles["speed"] = (battles["f_speed"] - battles["s_speed"])
    
    # Delete original values
    battles = battles\
        .sort_values(['battle_number']) \
        .reset_index() \
        .drop(["index","battle_number", "first_pokemon", "second_pokemon", "f_#", "s_#"], axis=1)
    return battles

print(battles.head())
train = merge_data(battles)
train.head()
# Out:
#    battle_number  first_pokemon  second_pokemon  winner
# 0              0            266             298       1
# 1              1            702             701       1
# 2              2            191             668       1
# 3              3            237             683       1
# 4              4            151             231       0
#    winner f_type_1  f_type_2      f_hp  f_attack  f_defense  f_sp_atk  \
# 0       1     Rock    Ground  0.192913  0.318919   0.200000  0.190217
# 1       1    Grass  Fighting  0.354331  0.459459   0.297778  0.434783
# 2       1    Fairy    Flying  0.212598  0.189189   0.355556  0.380435
# 3       1     Fire      None  0.153543  0.189189   0.155556  0.326087
# 4       0     Rock     Water  0.271654  0.297297   0.533333  0.570652
#
#    f_sp_def   f_speed  f_generation    ...     s_sp_atk  s_sp_def   s_speed  \
# 0  0.142857  0.205714             2    ...     0.271739  0.095238  0.314286
# 1  0.519048  0.588571             5    ...     0.336957  0.333333  0.588571
# 2  0.404762  0.200000             2    ...     0.625000  0.357143  0.200000
# 3  0.095238  0.085714             2    ...     0.271739  0.333333  0.245714
# 4  0.238095  0.285714             1    ...     0.000000  1.000000  0.000000
#
#    s_generation  s_legendary  f_t1  f_t2  s_t1  s_t2     speed
# 0             3            0   1.0   0.5   4.0   1.0 -0.108571
# 1             5            1   2.0   2.0   0.5   1.0  0.000000
# 2             5            0   1.0   1.0   1.0   0.0  0.000000
# 3             5            0   0.5   0.0   1.0   0.0 -0.160000
# 4             2            0   2.0   2.0   1.0   1.0  0.285714
#
# [5 rows x 26 columns]

# %%
# Transform pokemon type to dummy values
train = pd.get_dummies(train)

# %%
# Transform data to get train set 
Y_train = train["winner"]
X_train = train.drop(labels=["winner"],axis=1)

print(X_train.shape)
print(Y_train.shape)
# Out:
# (50000, 95)
# (50000,)

# %%
# Separate features and labels on training set
X_train, X_val, y_train, y_val = train_test_split(X_train, Y_train, test_size=0.1, random_state = 3)

# %%
model = GradientBoostingClassifier(learning_rate=0.01,
                                   min_samples_split=3,
                                   max_depth=10,
                                   n_estimators=2000,
                                   random_state=2)

# %%
model.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.01, loss='deviance', max_depth=10,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=3,
#               min_weight_fraction_leaf=0.0, n_estimators=2000,
#               presort='auto', random_state=2, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
y_val = np.array(y_val, dtype='int32')
y_val
# Out:
# array([0, 1, 0, ..., 1, 0, 1], dtype=int32)

# %%
# Predict values
predictions = model.predict(X_val)
res = model.score(X_val, y_val)
predictions
# Out:
# array([0, 1, 0, ..., 0, 0, 1])

# %%
res
# Out:
# 0.9814

# %%
# Prepare test data
X_test = merge_data(test)
X_test = pd.get_dummies(X_test)
X_test.head()
# Out:
#        f_hp  f_attack       ...        s_type_2_Steel  s_type_2_Water
# 0  0.311024  0.470270       ...                     0               0
# 1  0.287402  0.481081       ...                     0               0
# 2  0.307087  0.540541       ...                     0               0
# 3  0.271654  0.270270       ...                     0               0
# 4  0.153543  0.297297       ...                     0               0
#
# [5 rows x 95 columns]

# %%
predictions_test = model.predict(X_test)
predictions_test
result = np.squeeze(np.around(predictions_test).astype(int))
result
# Out:
# array([0, 1, 0, ..., 0, 0, 1])

# %%
data_to_submit = pd.DataFrame(columns=['Winner'])
data_to_submit['Winner'] = result
data_to_submit.insert(0, 'battle_number', range(0, len(data_to_submit)))
data_to_submit
data_to_submit.to_csv('submission.csv', index = False)
data_to_submit
# Out:
#       battle_number  Winner
# 0                 0       0
# 1                 1       1
# 2                 2       0
# 3                 3       1
# 4                 4       0
# 5                 5       0
# 6                 6       0
# 7                 7       1
# 8                 8       0
# 9                 9       0
# 10               10       1
# 11               11       0
# 12               12       1
# 13               13       0
# 14               14       1
# 15               15       1
# 16               16       0
# 17               17       1
# 18               18       1
# 19               19       1
# 20               20       0
# 21               21       0
# 22               22       0
# 23               23       1
# 24               24       1
# 25               25       1
# 26               26       0
# 27               27       1
# 28               28       0
# 29               29       0
# ...             ...     ...
# 9970           9970       0
# 9971           9971       1
# 9972           9972       1
# 9973           9973       0
# 9974           9974       0
# 9975           9975       1
# 9976           9976       1
# 9977           9977       0
# 9978           9978       0
# 9979           9979       1
# 9980           9980       0
# 9981           9981       0
# 9982           9982       0
# 9983           9983       1
# 9984           9984       1
# 9985           9985       1
# 9986           9986       1
# 9987           9987       0
# 9988           9988       1
# 9989           9989       0
# 9990           9990       1
# 9991           9991       1
# 9992           9992       0
# 9993           9993       1
# 9994           9994       1
# 9995           9995       1
# 9996           9996       1
# 9997           9997       0
# 9998           9998       0
# 9999           9999       1
#
# [10000 rows x 2 columns]
